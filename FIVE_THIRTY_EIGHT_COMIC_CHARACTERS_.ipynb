# %% [markdown]
# ## IMPORT LIBRARIES

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("C:/Users/HP/OneDrive/Desktop/marvel-wikia-data.csv")

# %%
data.shape
# Out:
# (16376, 13)

# %%
data.head()
# Out:
#    page_id                                 name  \
# 0     1678            Spider-Man (Peter Parker)
# 1     7139      Captain America (Steven Rogers)
# 2    64786  Wolverine (James \"Logan\" Howlett)
# 3     1868    Iron Man (Anthony \"Tony\" Stark)
# 4     2460                  Thor (Thor Odinson)
#
#                                    urlslug                ID  \
# 0              \/Spider-Man_(Peter_Parker)   Secret Identity
# 1        \/Captain_America_(Steven_Rogers)   Public Identity
# 2  \/Wolverine_(James_%22Logan%22_Howlett)   Public Identity
# 3    \/Iron_Man_(Anthony_%22Tony%22_Stark)   Public Identity
# 4                    \/Thor_(Thor_Odinson)  No Dual Identity
#
#                 ALIGN         EYE        HAIR              SEX  GSM  \
# 0     Good Characters  Hazel Eyes  Brown Hair  Male Characters  NaN
# 1     Good Characters   Blue Eyes  White Hair  Male Characters  NaN
# 2  Neutral Characters   Blue Eyes  Black Hair  Male Characters  NaN
# ...

# %%
data.columns
# Out:
# Index(['page_id', 'name', 'urlslug', 'ID', 'ALIGN', 'EYE', 'HAIR', 'SEX',
#        'GSM', 'ALIVE', 'APPEARANCES', 'FIRST APPEARANCE', 'Year'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16376 entries, 0 to 16375
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   page_id           16376 non-null  int64
#  1   name              16376 non-null  object
#  2   urlslug           16376 non-null  object
#  3   ID                12606 non-null  object
#  4   ALIGN             13564 non-null  object
#  5   EYE               6609 non-null   object
#  6   HAIR              12112 non-null  object
#  7   SEX               15522 non-null  object
#  8   GSM               90 non-null     object
#  9   ALIVE             16373 non-null  object
#  10  APPEARANCES       15280 non-null  float64
#  11  FIRST APPEARANCE  15561 non-null  object
#  12  Year              15561 non-null  float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 1.6+ MB

# %%
data = data.drop(['page_id', 'urlslug', 'GSM'], axis=1)

# %%
data.duplicated().value_counts()
# Out:
# False    16376
# Name: count, dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# name                   0
# ID                  3770
# ALIGN               2812
# EYE                 9767
# HAIR                4264
# SEX                  854
# ALIVE                  3
# APPEARANCES         1096
# FIRST APPEARANCE     815
# Year                 815
# dtype: int64

# %% [markdown]
# # IMPUTATION METHOD

# %%
# !pip install feature_engine -q

# %%
from feature_engine.imputation import CategoricalImputer

# %%
cat_columns=data.select_dtypes(include="object").columns

# %%
cat_columns
# Out:
# Index(['name', 'ID', 'ALIGN', 'EYE', 'HAIR', 'SEX', 'ALIVE',
#        'FIRST APPEARANCE'],
#       dtype='object')

# %%
cat_imputer= CategoricalImputer(imputation_method='missing',variables=['ALIGN','EYE','HAIR','ID','SEX','FIRST APPEARANCE'])

# %%
data=cat_imputer.fit_transform(data)

# %%
from feature_engine.imputation import MeanMedianImputer

# %%
num_columns=data.select_dtypes(include="number").columns

# %%
num_columns
# Out:
# Index(['APPEARANCES', 'Year'], dtype='object')

# %%
num_imputer=MeanMedianImputer(imputation_method='median',variables=['APPEARANCES','Year'])

# %%
data=num_imputer.fit_transform(data)

# %%
data.isnull().sum()
# Out:
# name                0
# ID                  0
# ALIGN               0
# EYE                 0
# HAIR                0
# SEX                 0
# ALIVE               3
# APPEARANCES         0
# FIRST APPEARANCE    0
# Year                0
# dtype: int64

# %% [markdown]
# # **OUTLIERS**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# for i in data.select_dtypes(include="number").columns:
#   sns.boxplot(data[i])
#   plt.show()

# %%
# out_cols = ['APPEARANCES','Year']
# for cols in out_cols:
#     Q1 = data[cols].quantile(0.25)
#     Q3 = data[cols].quantile(0.75)
#     IQR = Q3-Q1
#     m1 = Q1-1.5*IQR
#     m2 = Q3+1.5*IQR
#     data[cols] = data[cols].clip(lower=m1,upper=m2)

# %%
# out_cols = ['APPEARANCES','Year']
# for cols in out_cols:
#   sns.boxplot(data[cols])
#   plt.show()

# %% [markdown]
# # ENCODING

# %%
from sklearn.preprocessing import LabelEncoder

# %%
L_encoder = LabelEncoder()

# %%
# encoding categorical data by looping through columns
for i in cat_columns:
    data[i] = L_encoder.fit_transform(data[i])

# %%
data.head()
# Out:
#     name  ID  ALIGN  EYE  HAIR  SEX  ALIVE  APPEARANCES  FIRST APPEARANCE  \
# 0  13954   4      1    9     6    3      1       4043.0                99
# 1   2327   3      1    3    24    3      1       3360.0               503
# 2  15996   3      3    3     2    3      1       3061.0               739
# 3   6771   3      1    3     2    3      1       2961.0               521
# 4  14709   2      1    3     3    3      1       2258.0               650
#
#      Year
# 0  1962.0
# 1  1941.0
# 2  1974.0
# 3  1963.0
# 4  1950.0

# %% [markdown]
# # SCALING

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss=StandardScaler()

# %%
data=ss.fit_transform(data)

# %%
data=pd.DataFrame(data)

# %%
data.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  1.219818  1.010219 -0.029306 -0.102917 -0.400083  0.465261  0.545549
# 1 -1.239702  0.160710 -0.029306 -1.372653  2.392852  0.465261  0.545549
# 2  1.651773  0.160710  1.860149 -1.372653 -1.020736  0.465261  0.545549
# 3 -0.299640  0.160710 -0.029306 -1.372653 -1.020736  0.465261  0.545549
# 4  1.379527 -0.688800 -0.029306 -1.372653 -0.865572  0.465261  0.545549
#
#            7         8         9
# 0  43.227963 -1.400309 -1.208566
# 1  35.896106  0.274550 -2.302384
# 2  32.686405  1.252933 -0.583528
# 3  31.612927  0.349172 -1.156480
# 4  24.066374  0.883967 -1.833605

# %%
data.columns=['name','ID','ALIGN','EYE','HAIR','SEX','ALIVE','APPEARANCES','FIRST APPEARANCE','Year']

# %%
data.head()
# Out:
#        name        ID     ALIGN       EYE      HAIR       SEX     ALIVE  \
# 0  1.219818  1.010219 -0.029306 -0.102917 -0.400083  0.465261  0.545549
# 1 -1.239702  0.160710 -0.029306 -1.372653  2.392852  0.465261  0.545549
# 2  1.651773  0.160710  1.860149 -1.372653 -1.020736  0.465261  0.545549
# 3 -0.299640  0.160710 -0.029306 -1.372653 -1.020736  0.465261  0.545549
# 4  1.379527 -0.688800 -0.029306 -1.372653 -0.865572  0.465261  0.545549
#
#    APPEARANCES  FIRST APPEARANCE      Year
# 0    43.227963         -1.400309 -1.208566
# 1    35.896106          0.274550 -2.302384
# 2    32.686405          1.252933 -0.583528
# 3    31.612927          0.349172 -1.156480
# 4    24.066374          0.883967 -1.833605

# %%
# spliting data into train and test data
from sklearn.model_selection import train_test_split

# %%
# Assuming 'data' is your DataFrame and 'APPEARANCES' is the target variable
X = data.drop('APPEARANCES', axis=1)  # Features
Y = data['APPEARANCES']  # Target variable

# Now you can split the data
Xtrain, xtest, Ytrain, ytest = train_test_split(X,Y, test_size=0.3, random_state=1)

# %% [markdown]
# # XG BOOST

# %%
# !pip install xgboost
# Out:
# ...
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB 435.7 kB/s eta 0:04:47
#    ---------------------------------------- 0.2/124.9 MB 1.8 MB/s eta 0:01:10
#    ---------------------------------------- 0.6/124.9 MB 4.0 MB/s eta 0:00:32
#    ---------------------------------------- 1.2/124.9 MB 6.0 MB/s eta 0:00:21
#     --------------------------------------- 1.8/124.9 MB 7.0 MB/s eta 0:00:18
#     --------------------------------------- 2.1/124.9 MB 6.9 MB/s eta 0:00:18
#     --------------------------------------- 2.5/124.9 MB 7.4 MB/s eta 0:00:17
#     --------------------------------------- 3.0/124.9 MB 7.6 MB/s eta 0:00:17
#    - -------------------------------------- 3.3/124.9 MB 7.9 MB/s eta 0:00:16
#    - -------------------------------------- 4.0/124.9 MB 8.2 MB/s eta 0:00:15
# ...

# %%
import xgboost as xgb
xgb_class=xgb.XGBRegressor()
xgb_class.fit(Xtrain,Ytrain)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
y_pred=xgb_class.predict(xtest)
y_pred
# Out:
# array([-0.5951882 , -0.15416363, -0.04779498, ..., -0.13645169,
#        -0.16914661, -0.1462971 ], dtype=float32)

# %%
from sklearn.metrics import r2_score
r2_score(y_pred,ytest)
# Out:
# -0.5329199981371444

# %%
xgb_class.score(Xtrain,Ytrain)
# Out:
# 0.9529690863015122

# %%
xgb_class.score(xtest, ytest)  # Pass the test features (xtest) and true labels (ytest)
# Out:
# 0.07453446597946034

# %%
from sklearn.metrics import r2_score

# %%
# Assuming 'xgb_class' is your trained XGBoost model
y_train_pred = xgb_class.predict(Xtrain)  # Generate predictions on the training set

r2 = r2_score(Ytrain, y_train_pred)  # Now calculate R^2
print(r2)
# Out:
# 0.9529690863015122

# %%
# r2=r2_score(Ytrain,y_train_pred)
# r2

# %%
y_test_pred=xgb_class.predict(xtest)
y_test_pred
# Out:
# array([-0.5951882 , -0.15416363, -0.04779498, ..., -0.13645169,
#        -0.16914661, -0.1462971 ], dtype=float32)

# %%
r2=r2_score(ytest,y_test_pred)
r2
# Out:
# 0.07453446597946034

# %% [markdown]
# # cross Validation

# %%
from sklearn.model_selection import cross_val_score
mse_scores = cross_val_score(xgb_class, X, Y, cv=5, scoring='r2')

# %%
print("R2 Scores:", mse_scores)
# Out:
# R2 Scores: [-1.05291884e-01 -8.15596753e+02 -5.20273130e+03 -1.28511426e+04
#  -1.86031378e+03]

# %%
print('Average cross-validation score: {:.4f}'.format(mse_scores.mean()))
# Out:
# Average cross-validation score: -4145.9780

# %% [markdown]
# # RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

# %%
rr= RandomForestRegressor()

# %%
X=data.drop(columns=['APPEARANCES'])
Y=data['APPEARANCES']

# %%
from sklearn.model_selection import train_test_split

# %%
Xtrain,xtest,Ytrain,ytest=train_test_split(X,Y,test_size=0.3,random_state= 1)

# %%
rr.fit(Xtrain,Ytrain)
# Out:
# RandomForestRegressor()

# %%
y3=rr.predict(xtest)
y4=rr.predict(Xtrain)

# %%
accuracy_train=r2_score(Ytrain,y4)
accuracy_test= r2_score(ytest,y3)

# %%
print("accuracy_train: ",accuracy_train)
print("accuracy_test: ",accuracy_test)
# Out:
# accuracy_train:  0.8760681272574874
# accuracy_test:  0.08254034616128025

# %%
para={'n_estimators':[100,200,300,400],'max_depth':[3,4,5,7,9]}

# %%
grid=GridSearchCV(estimator=rr,param_grid=para)

# %%
grid.fit(Xtrain,Ytrain)
# Out:
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [3, 4, 5, 7, 9],
#                          'n_estimators': [100, 200, 300, 400]})

# %%
grid.best_params_
# Out:
# {'max_depth': 4, 'n_estimators': 100}

# %%
y5=grid.predict(xtest)

# %%
accuracy_grid=r2_score(ytest,y5)
accuracy_grid
# Out:
# 0.1326973371700495

# %%
grid1=GridSearchCV

# %%
rf=RandomForestRegressor(n_estimators=150,max_depth=7)

# %%
rf.fit(Xtrain,Ytrain)
# Out:
# RandomForestRegressor(max_depth=7, n_estimators=150)

# %%
y6=rf.predict(xtest)

# %%
accuracy_ranF=r2_score(ytest,y6)
accuracy_ranF
# Out:
# 0.10294776902168778

# %%
grid_rf=GridSearchCV(estimator=rf,param_grid=para)

# %%
grid_rf.fit(Xtrain,Ytrain)
# Out:
# GridSearchCV(estimator=RandomForestRegressor(max_depth=7, n_estimators=150),
#              param_grid={'max_depth': [3, 4, 5, 7, 9],
#                          'n_estimators': [100, 200, 300, 400]})

# %%
y7 = grid_rf.predict(xtest)

# %%
accuracy_rF=r2_score(ytest,y6)
accuracy_rF
# Out:
# 0.10294776902168778

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
L_regression = LinearRegression()

# %%
L_regression.fit(Xtrain,Ytrain)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score

# %%
y_train_pred = L_regression.predict(Xtrain)
y_test_pred = L_regression.predict(xtest)
Train_accuracy = r2_score(Ytrain,y_train_pred)
Test_accuracy =  r2_score(ytest, y_test_pred)
print("TRAIN ACCURACY : ", Train_accuracy)
print("TEST ACCURACY : ", Test_accuracy)
# Out:
# TRAIN ACCURACY :  0.024714280736356065
# TEST ACCURACY :  0.02198946238035082
